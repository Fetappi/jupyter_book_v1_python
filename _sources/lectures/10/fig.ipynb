# %% [markdown]
# # Задание 3 Фигуры
# (HW10_fig)=

# %%
x_min, x_max = -5, 5
y_min, y_max = -5, 5
N_x, N_y = 1100, 1100

xs = np.linspace(x_min, x_max, N_x)
ys = np.linspace(y_max, y_min, N_y)

X, Y = np.meshgrid(xs, ys)

# %%
#прямая
def fig(x, y_1, a = -1, b = -1):
    y_2 = a*x + b
    return y_2 > y_1

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.imshow(fig(X, Y))

# %%
plt.imshow(fig(X, Y))

# %%
plt.imshow(fig(X, Y))
