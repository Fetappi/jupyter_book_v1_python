# %% [markdown]
# # Python в качестве калькулятора

# %%
a = 10
b = 6
b = a
a = 5
print(a)
print(b)
# Out:
# 5
# 10

# %%
a = 10
b = 2
c = a + b
print(c)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a ** b)
print(10 % 3)
# Out:
# 12
# 8
# 20
# 5.0
# 5
# 100
# 1

# %%
print( (3 ** 3) ** 2 )
# Out:
# 729

# %%
c = a + b
print(c)
# Out:
# 13

# %%
a = 1
b = 2
print(a == b)
print(a != b)
print(a < b)
print(a <= 10)
print(a >= b)
# Out:
# False
# True
# True
# True
# False

# %% [markdown]
# # Стандартные мат функции

# %%
a = 1 / 3
round(a, 3)
# Out:
# 0.333

# %%
c = abs(-10)
print(c)

c = pow(10, 3)
print(c)

c = round(10 / 3, 3)
print(c)

print
# Out:
# 10
# 1000
# 3.333

# %% [markdown]
# # Поток ввода вывода

# %%
print("Hello, what is ' '  your name?")
name = input()
print("Hi, ", name, "!", sep="")
# Out:
# Hello, what is ' '  your name? 10
# artem
# <class 'str'>
# Hi, artem!

# %%
name = input("Hello, what is your name?\n")
print("Hi, ", name, "!", sep="")
# Out:
# Hello, what is your name?
# Artem
# Hi, Artem!

# %%
age = int(input("What is your age? "))
print("В след году вам будет ", age + 1, " years old!", sep="")
# Out:
# What is your age? 27
# В след году вам будет28 years old!

# %% [markdown]
# # Объекты Python

# %%
x = 42

print(x.) #необходимое для хранения этого числа количество бит.
# в google colab ctr+space вызывает подсказку
# Out:
# 42

# %%
a = 42
b = 5
print("a=", a)
print("a = {}, b = {}".format(a, b))  # форматирование строки методом format
print(f"{a + b =}")
# print(type(a))
# Out:
# a= 42
# a = 42, b = 5
# a + b =47

# %%
print(f"a / b = {a / b}")
print(type(a / b))
# Out:
# a / b = 8.4
# <class 'float'>

# %%
c = 3.14151902352354789
d = c ** .5
# print(f"c = {c}, d = {d}")
print(f"d = {c:.5f}")
# Out:
# d = 3.14150

# %%
flag = True
print(type(flag))
# Out:
# <class 'bool'>

# %%
flag = True
print(type(flag))
print(f"True = {int(True)}")
print(f"False = {int(False)}")
print(isinstance(flag, int))
# Out:
# <class 'bool'>
# True = 1
# False = 0
# True

# %%
print(False and False)
print(False and True)
print(True and False)
print(True and True)
# Out:
# False
# False
# False
# True

# %%
print(False or False)
print(False or True)
print(True or False)
print(True or True)
# Out:
# False
# True
# True
# True

# %%
print(not False)
print(not True)
# Out:
# True
# False

# %% [markdown]
# # Ветвление

# %%
i = 2
flag = True
if i % 15 == 0:print('FizzBuzz, ')
elif i % 3 == 0:print('Fizz, ')
elif i % 5 == 0:print('Buzz, ')
else:print(f'{i}, ')
# Out:
# 2,

# %%
from random import randint


random_value = randint(0, 5)
print(random_value)
# Out:
# 1

# %%
from random import randint
random_value = randint(0, 10)                    # 0 или 1
print(f"Результат генерации: {random_value}")

# if random_value == 1:
#     print("Орёл")
# else:
#     print("Решка")

# или так

if (random_value):
    print("Орёл")
else:
    print("Решка")
# Out:
# Результат генерации: 10
# Орёл

# %%
x = 1
y = 5
if (x != 0) or (y / x > 0):
    print("do something")
# Out:
# do something

# %%
i = 0
while i < 10:
    i += 1
    if i%2 != 0: # i%2
        continue
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
def func(x):
    return x ** 2

print(func(2))
# Out:
# 4
